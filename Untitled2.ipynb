# %%
import tensorflow as tf
import functions as func
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.nan)
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 300000
batch_size = 64
display_step = 10

# %%
# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    
    x = tf.reshape(x, shape=[64, 28, 28, 1])

    # Convolution Layer
    conv1 = func.conv2d(x, weights['wc1'], biases['bc1'])
    # Pooling (down-sampling)
    p = func.extract_patches(conv1, 'SAME', 2, 2)
    f = func.majority_frequency(p)
#     maxpooling
    maxpool = func.max_pool(p)

    # Convolution Layer
    conv2 = func.conv2d(maxpool, weights['wc2'], biases['bc2'])
#     Pooling (down-sampling)
    p = func.extract_patches(conv2, 'SAME', 2, 2)
    f = func.majority_frequency(p)
#     maxpooling
    maxpool = func.max_pool(p)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(maxpool, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
def compute_out(conv):
    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)
    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Create model
def test_conv_net(x, weights, biases, dropout):
    # Reshape input picture
    
    x = tf.reshape(x, shape=[64, 28, 28, 1])

    # Convolution Layer
    conv1 = func.conv2d(x, weights['wc1'], biases['bc1'])
    # Pooling (down-sampling)
    p = func.extract_patches(conv1, 'SAME', 2, 2)
    f = func.majority_frequency(p)
#     maxpooling
    maxpool = func.max_pool(p)
#     other pooling method
    majoritypooling = func.majority_pool(p, f)
    wmxpooling = func.weight_pool(p=p, f=f, pool_fun=func.max_pool, reduce_fun=tf.reduce_max)
    wmjpooling = func.weight_pool(p=p, f=f, pool_fun=func.majority_pool, reduce_fun=tf.reduce_max)
    mxwpooling = func.pool_weight(p=p, f=f, pool_fun=func.max_pool, reduce_fun=tf.reduce_max)
    mjwpooling = func.pool_weight(p=p, f=f, pool_fun=func.majority_pool, reduce_fun=tf.reduce_max)
    pcapooling = func.pca_pool(p)
#     difference between maxpooling and other pooling method
    Diff1 = [tf.reduce_sum(majoritypooling - maxpool), tf.reduce_sum(wmxpooling - maxpool), 
             tf.reduce_sum(wmjpooling - maxpool), tf.reduce_sum(mxwpooling - maxpool), 
             tf.reduce_sum(mjwpooling - maxpool), tf.reduce_sum(pcapooling - maxpool)]
 
    
    
    # Convolution Layer
    conv2m = func.conv2d(maxpool, weights['wc2'], biases['bc2'])
    conv2mj = func.conv2d(majoritypooling, weights['wc2'], biases['bc2'])
    conv2wmx = func.conv2d(wmxpooling, weights['wc2'], biases['bc2'])
    conv2wmj = func.conv2d(wmjpooling, weights['wc2'], biases['bc2'])
    conv2mxw = func.conv2d(mxwpooling, weights['wc2'], biases['bc2'])
    conv2mjw = func.conv2d(mjwpooling, weights['wc2'], biases['bc2'])
    conv2pca = func.conv2d(pcapooling, weights['wc2'], biases['bc2'])
    
#     Pooling (down-sampling)
    pm = func.extract_patches(conv2m, 'SAME', 2, 2)
    pmj = func.extract_patches(conv2mj, 'SAME', 2, 2)
    pwmx = func.extract_patches(conv2wmx, 'SAME', 2, 2)
    pwmj = func.extract_patches(conv2wmj, 'SAME', 2, 2)
    pmxw = func.extract_patches(conv2mxw, 'SAME', 2, 2)
    pmjw = func.extract_patches(conv2mjw, 'SAME', 2, 2)
    ppca = func.extract_patches(conv2pca, 'SAME', 2, 2)
    
    fmj = func.majority_frequency(pmj)
    fwmx = func.majority_frequency(pwmx)
    fwmj = func.majority_frequency(pwmj)
    fmxw = func.majority_frequency(pmxw)
    fmjw = func.majority_frequency(pmjw)
    
#     maxpooling
    maxpool = func.max_pool(pm)
#     other pooling method
    majoritypooling = func.majority_pool(pmj, fmj)
    wmxpooling = func.weight_pool(p=pwmx, f=fwmx, pool_fun=func.max_pool, reduce_fun=tf.reduce_max)
    wmjpooling = func.weight_pool(p=pwmj, f=fwmj, pool_fun=func.majority_pool, reduce_fun=tf.reduce_max)
    mxwpooling = func.pool_weight(p=pmxw, f=fmxw, pool_fun=func.max_pool, reduce_fun=tf.reduce_max)
    mjwpooling = func.pool_weight(p=pmjw, f=fmjw, pool_fun=func.majority_pool, reduce_fun=tf.reduce_max)
    pcapooling = func.pca_pool(ppca)
#     difference between maxpooling and other pooling method
    Diff2 = [tf.reduce_sum(majoritypooling - maxpool), tf.reduce_sum(wmxpooling - maxpool), 
             tf.reduce_sum(wmjpooling - maxpool), tf.reduce_sum(mxwpooling - maxpool), 
             tf.reduce_sum(mjwpooling - maxpool), tf.reduce_sum(pcapooling - maxpool)]

    
    Out = []
    for temp in [maxpool, majoritypooling, wmxpooling, wmjpooling, mxwpooling, mjwpooling, pcapooling]:
        Out.append(compute_out(temp))
        
    return Diff1, Diff2, Out

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
Diff1, Diff2, Out = test_conv_net(x, weights, biases, keep_prob)
lost = []
for temp in Out:
    lost.append(tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=temp, labels=y)))

correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# [64, 14, 14, 4, 32]
# [64, 7, 7, 4, 64]
# [64, 14, 14, 4, 32]
# [64, 14, 14, 4, 32]
# [64, 7, 7, 4, 64]
# [64, 7, 7, 4, 64]
# [64, 7, 7, 4, 64]
# [64, 7, 7, 4, 64]
# [64, 7, 7, 4, 64]
# [64, 7, 7, 4, 64]

# %%
# Initializing the variables
init = tf.global_variables_initializer()
# f = open('output.txt', 'w')
D1 = []
D2 = []
L = []
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
#     while step < 2:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            tempd1, tempd2, loss, cos, acc = sess.run([Diff1, Diff2, lost, cost, accuracy], 
                                               feed_dict={x: batch_x,
                                                          y: batch_y,
                                                          keep_prob: 1.})
            D1.append(tempd1)
            D2.append(tempd2)
            L.append(loss)
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(cos) + 
                  "\nTraining Accuracy= " + "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    
#     Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:64], y: mnist.test.labels[:64],
keep_prob: 1.}))
# Out:
# Iter 640, Minibatch Loss= 18178.472656
# Training Accuracy= 0.31250
# Iter 1280, Minibatch Loss= 11644.433594
# Training Accuracy= 0.50000
# Iter 1920, Minibatch Loss= 7030.811035
# Training Accuracy= 0.60938
# Iter 2560, Minibatch Loss= 5145.743652
# Training Accuracy= 0.67188
# Iter 3200, Minibatch Loss= 4546.321289
# Training Accuracy= 0.76562
# Iter 3840, Minibatch Loss= 4079.187744
# Training Accuracy= 0.70312
# Iter 4480, Minibatch Loss= 3598.559326
# Training Accuracy= 0.87500
# Iter 5120, Minibatch Loss= 4787.828613
# Training Accuracy= 0.70312
# Iter 5760, Minibatch Loss= 3026.008301
# Training Accuracy= 0.85938
# Iter 6400, Minibatch Loss= 3320.404785
# Training Accuracy= 0.79688
# Iter 7040, Minibatch Loss= 2318.599121
# Training Accuracy= 0.81250
# Iter 7680, Minibatch Loss= 1501.519165
# Training Accuracy= 0.90625
# Iter 8320, Minibatch Loss= 545.451172
# Training Accuracy= 0.92188
# Iter 8960, Minibatch Loss= 2784.787109
# Training Accuracy= 0.87500
# Iter 9600, Minibatch Loss= 1942.253418
# Training Accuracy= 0.85938
# Iter 10240, Minibatch Loss= 2011.837891
# Training Accuracy= 0.90625
# Iter 10880, Minibatch Loss= 1425.579346
# Training Accuracy= 0.90625
# Iter 11520, Minibatch Loss= 1153.400269
# Training Accuracy= 0.89062
# Iter 12160, Minibatch Loss= 653.010376
# Training Accuracy= 0.92188
# Iter 12800, Minibatch Loss= 1503.665161
# Training Accuracy= 0.87500
# Iter 13440, Minibatch Loss= 1543.478271
# Training Accuracy= 0.95312
# Iter 14080, Minibatch Loss= 302.713745
# Training Accuracy= 0.95312
# Iter 14720, Minibatch Loss= 1266.424561
# Training Accuracy= 0.90625
# Iter 15360, Minibatch Loss= 1811.860840
# Training Accuracy= 0.90625
# Iter 16000, Minibatch Loss= 3000.026123
# Training Accuracy= 0.92188
# Iter 16640, Minibatch Loss= 739.506348
# Training Accuracy= 0.93750
# Iter 17280, Minibatch Loss= 171.410461
# Training Accuracy= 0.95312
# Iter 17920, Minibatch Loss= 1218.574951
# Training Accuracy= 0.92188
# Iter 18560, Minibatch Loss= 643.112549
# Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 2302.463135
# Training Accuracy= 0.87500
# Iter 19840, Minibatch Loss= 706.087158
# Training Accuracy= 0.87500
# Iter 20480, Minibatch Loss= 910.033875
# Training Accuracy= 0.93750
# Iter 21120, Minibatch Loss= 321.757477
# Training Accuracy= 0.93750
# Iter 21760, Minibatch Loss= 1500.022827
# Training Accuracy= 0.84375
# Iter 22400, Minibatch Loss= 660.951660
# Training Accuracy= 0.92188
# Iter 23040, Minibatch Loss= 1226.041992
# Training Accuracy= 0.90625
# Iter 23680, Minibatch Loss= 764.429688
# Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 2166.877930
# Training Accuracy= 0.92188
# Iter 24960, Minibatch Loss= 442.197662
# Training Accuracy= 0.93750
# Iter 25600, Minibatch Loss= 1196.788696
# Training Accuracy= 0.93750
# Iter 26240, Minibatch Loss= 1621.611816
# Training Accuracy= 0.85938
# Iter 26880, Minibatch Loss= 643.025269
# Training Accuracy= 0.93750
# Iter 27520, Minibatch Loss= 641.207336
# Training Accuracy= 0.96875
# Iter 28160, Minibatch Loss= 2470.205566
# Training Accuracy= 0.84375
# Iter 28800, Minibatch Loss= 918.328979
# Training Accuracy= 0.96875
# Iter 29440, Minibatch Loss= 163.923813
# Training Accuracy= 0.96875
# Iter 30080, Minibatch Loss= 390.144623
# Training Accuracy= 0.95312
# Iter 30720, Minibatch Loss= 544.568115
# Training Accuracy= 0.96875
# Iter 31360, Minibatch Loss= 991.273743
# Training Accuracy= 0.93750
# Iter 32000, Minibatch Loss= 614.520203
# Training Accuracy= 0.95312
# Iter 32640, Minibatch Loss= 1424.842773
# Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 743.476685
# Training Accuracy= 0.95312
# Iter 33920, Minibatch Loss= 477.961639
# Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 3011.477051
# Training Accuracy= 0.87500
# Iter 35200, Minibatch Loss= 420.482727
# Training Accuracy= 0.90625
# Iter 35840, Minibatch Loss= 250.886368
# Training Accuracy= 0.95312
# Iter 36480, Minibatch Loss= 316.910980
# Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 125.915527
# Training Accuracy= 0.98438
# Iter 37760, Minibatch Loss= 1067.308838
# Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 53.738922
# Training Accuracy= 0.98438
# Iter 39040, Minibatch Loss= 1476.813843
# Training Accuracy= 0.90625
# Iter 39680, Minibatch Loss= 531.827637
# Training Accuracy= 0.95312
# Iter 40320, Minibatch Loss= 523.889160
# Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 1022.415649
# Training Accuracy= 0.93750
# Iter 41600, Minibatch Loss= 294.712372
# Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 608.211304
# Training Accuracy= 0.93750
# Iter 42880, Minibatch Loss= 311.459045
# Training Accuracy= 0.95312
# Iter 43520, Minibatch Loss= 139.899475
# Training Accuracy= 0.96875
# Iter 44160, Minibatch Loss= 669.132812
# Training Accuracy= 0.89062
# Iter 44800, Minibatch Loss= 587.861145
# Training Accuracy= 0.93750
# Iter 45440, Minibatch Loss= 59.764648
# Training Accuracy= 0.98438
# Iter 46080, Minibatch Loss= 108.840149
# Training Accuracy= 0.98438
# Iter 46720, Minibatch Loss= 421.621887
# Training Accuracy= 0.96875
# Iter 47360, Minibatch Loss= 396.936340
# Training Accuracy= 0.93750
# Iter 48000, Minibatch Loss= 427.899658
# Training Accuracy= 0.90625
# Iter 48640, Minibatch Loss= 458.252533
# Training Accuracy= 0.95312
# Iter 49280, Minibatch Loss= 295.601807
# Training Accuracy= 0.95312
# Iter 49920, Minibatch Loss= 135.586884
# Training Accuracy= 0.96875
# Iter 50560, Minibatch Loss= 475.783966
# Training Accuracy= 0.95312
# Iter 51200, Minibatch Loss= 362.688568
# Training Accuracy= 0.95312
# Iter 51840, Minibatch Loss= 85.236954
# Training Accuracy= 0.96875
# Iter 52480, Minibatch Loss= 162.785858
# Training Accuracy= 0.96875
# Iter 53120, Minibatch Loss= 433.039764
# Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 391.300720
# Training Accuracy= 0.92188
# Iter 54400, Minibatch Loss= 228.005463
# Training Accuracy= 0.96875
# Iter 55040, Minibatch Loss= 754.969849
# Training Accuracy= 0.96875
# Iter 55680, Minibatch Loss= 179.359207
# Training Accuracy= 0.96875
# Iter 56320, Minibatch Loss= 521.897888
# Training Accuracy= 0.93750
# Iter 56960, Minibatch Loss= 491.784546
# Training Accuracy= 0.96875
# Iter 57600, Minibatch Loss= 942.493042
# Training Accuracy= 0.92188
# Iter 58240, Minibatch Loss= 250.639587
# Training Accuracy= 0.95312
# Iter 58880, Minibatch Loss= 916.463745
# Training Accuracy= 0.95312
# Iter 59520, Minibatch Loss= 269.878357
# Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 1296.526123
# Training Accuracy= 0.89062
# Iter 60800, Minibatch Loss= 293.616455
# Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 329.673065
# Training Accuracy= 0.95312
# Iter 62080, Minibatch Loss= 365.342255
# Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 431.576111
# Training Accuracy= 0.93750
# Iter 63360, Minibatch Loss= 524.907593
# Training Accuracy= 0.90625
# Iter 64000, Minibatch Loss= 133.407715
# Training Accuracy= 0.96875
# Iter 64640, Minibatch Loss= 933.245483
# Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 572.087219
# Training Accuracy= 0.95312
# Iter 65920, Minibatch Loss= 488.409058
# Training Accuracy= 0.93750
# Iter 66560, Minibatch Loss= 436.644073
# Training Accuracy= 0.95312
# Iter 67200, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 67840, Minibatch Loss= 1362.863281
# Training Accuracy= 0.90625
# Iter 68480, Minibatch Loss= 706.754822
# Training Accuracy= 0.92188
# Iter 69120, Minibatch Loss= 55.103302
# Training Accuracy= 0.98438
# Iter 69760, Minibatch Loss= 673.582764
# Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 236.540375
# Training Accuracy= 0.98438
# Iter 71040, Minibatch Loss= 309.145447
# Training Accuracy= 0.93750
# Iter 71680, Minibatch Loss= 47.022049
# Training Accuracy= 0.98438
# Iter 72320, Minibatch Loss= 523.879028
# Training Accuracy= 0.93750
# Iter 72960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 73600, Minibatch Loss= 17.948639
# Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 89.974060
# Training Accuracy= 0.96875
# Iter 74880, Minibatch Loss= 518.641357
# Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 55.672852
# Training Accuracy= 0.98438
# Iter 76160, Minibatch Loss= 59.558899
# Training Accuracy= 0.98438
# Iter 76800, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 77440, Minibatch Loss= 188.733490
# Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 191.883530
# Training Accuracy= 0.93750
# Iter 78720, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 79360, Minibatch Loss= 275.193115
# Training Accuracy= 0.96875
# Iter 80000, Minibatch Loss= 177.037415
# Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 117.121216
# Training Accuracy= 0.96875
# Iter 81280, Minibatch Loss= 502.093109
# Training Accuracy= 0.92188
# Iter 81920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 82560, Minibatch Loss= 156.042343
# Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 162.547394
# Training Accuracy= 0.98438
# Iter 83840, Minibatch Loss= 21.092468
# Training Accuracy= 0.98438
# Iter 84480, Minibatch Loss= 1073.930786
# Training Accuracy= 0.90625
# Iter 85120, Minibatch Loss= 294.912781
# Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 250.124603
# Training Accuracy= 0.93750
# Iter 86400, Minibatch Loss= 454.444183
# Training Accuracy= 0.95312
# Iter 87040, Minibatch Loss= 410.616943
# Training Accuracy= 0.95312
# Iter 87680, Minibatch Loss= 83.652390
# Training Accuracy= 0.98438
# Iter 88320, Minibatch Loss= 177.254791
# Training Accuracy= 0.98438
# Iter 88960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 89600, Minibatch Loss= 45.897064
# Training Accuracy= 0.98438
# Iter 90240, Minibatch Loss= 824.665039
# Training Accuracy= 0.93750
# Iter 90880, Minibatch Loss= 125.668488
# Training Accuracy= 0.96875
# Iter 91520, Minibatch Loss= 51.401062
# Training Accuracy= 0.93750
# Iter 92160, Minibatch Loss= 134.735352
# Training Accuracy= 0.98438
# Iter 92800, Minibatch Loss= 133.654922
# Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 320.373962
# Training Accuracy= 0.92188
# Iter 94080, Minibatch Loss= 204.903595
# Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 114.632294
# Training Accuracy= 0.96875
# Iter 95360, Minibatch Loss= 262.625549
# Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 345.439301
# Training Accuracy= 0.93750
# Iter 96640, Minibatch Loss= 898.451477
# Training Accuracy= 0.95312
# Iter 97280, Minibatch Loss= 42.374237
# Training Accuracy= 0.96875
# Iter 97920, Minibatch Loss= 104.573952
# Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 125.574814
# Training Accuracy= 0.93750
# Iter 99200, Minibatch Loss= 43.402252
# Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 223.013794
# Training Accuracy= 0.95312
# Iter 100480, Minibatch Loss= 41.494888
# Training Accuracy= 0.98438
# Iter 101120, Minibatch Loss= 286.425873
# Training Accuracy= 0.98438
# Iter 101760, Minibatch Loss= 117.558044
# Training Accuracy= 0.98438
# Iter 102400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 103040, Minibatch Loss= 127.300705
# Training Accuracy= 0.96875
# Iter 103680, Minibatch Loss= 379.003113
# Training Accuracy= 0.93750
# Iter 104320, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 104960, Minibatch Loss= 133.112854
# Training Accuracy= 0.96875
# Iter 105600, Minibatch Loss= 434.821228
# Training Accuracy= 0.92188
# Iter 106240, Minibatch Loss= 22.178040
# Training Accuracy= 0.98438
# Iter 106880, Minibatch Loss= 292.023254
# Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 126.212326
# Training Accuracy= 0.95312
# Iter 108160, Minibatch Loss= 315.772095
# Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 190.929153
# Training Accuracy= 0.92188
# Iter 109440, Minibatch Loss= 265.773071
# Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 239.712906
# Training Accuracy= 0.93750
# Iter 110720, Minibatch Loss= 161.154297
# Training Accuracy= 0.93750
# Iter 111360, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 112000, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 112640, Minibatch Loss= 3.111328
# Training Accuracy= 0.98438
# Iter 113280, Minibatch Loss= 247.069778
# Training Accuracy= 0.92188
# Iter 113920, Minibatch Loss= 344.658234
# Training Accuracy= 0.98438
# Iter 114560, Minibatch Loss= 200.208878
# Training Accuracy= 0.95312
# Iter 115200, Minibatch Loss= 147.034134
# Training Accuracy= 0.98438
# Iter 115840, Minibatch Loss= 836.131714
# Training Accuracy= 0.92188
# Iter 116480, Minibatch Loss= 139.899292
# Training Accuracy= 0.98438
# Iter 117120, Minibatch Loss= 141.784210
# Training Accuracy= 0.95312
# Iter 117760, Minibatch Loss= 125.242706
# Training Accuracy= 0.96875
# Iter 118400, Minibatch Loss= 137.279449
# Training Accuracy= 0.98438
# Iter 119040, Minibatch Loss= 271.215942
# Training Accuracy= 0.95312
# Iter 119680, Minibatch Loss= 62.845001
# Training Accuracy= 0.98438
# Iter 120320, Minibatch Loss= 141.710999
# Training Accuracy= 0.98438
# Iter 120960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 121600, Minibatch Loss= 137.279480
# Training Accuracy= 0.98438
# Iter 122240, Minibatch Loss= 26.048981
# Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 62.659088
# Training Accuracy= 0.95312
# Iter 123520, Minibatch Loss= 352.865540
# Training Accuracy= 0.95312
# Iter 124160, Minibatch Loss= 125.914215
# Training Accuracy= 0.98438
# Iter 124800, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 125440, Minibatch Loss= 167.403900
# Training Accuracy= 0.95312
# Iter 126080, Minibatch Loss= 211.023727
# Training Accuracy= 0.93750
# Iter 126720, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 127360, Minibatch Loss= 107.464066
# Training Accuracy= 0.95312
# Iter 128000, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 128640, Minibatch Loss= 319.642761
# Training Accuracy= 0.92188
# Iter 129280, Minibatch Loss= 13.531799
# Training Accuracy= 0.98438
# Iter 129920, Minibatch Loss= 271.481049
# Training Accuracy= 0.95312
# Iter 130560, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 131200, Minibatch Loss= 1220.494629
# Training Accuracy= 0.90625
# Iter 131840, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 132480, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 133120, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 133760, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 134400, Minibatch Loss= 384.094421
# Training Accuracy= 0.95312
# Iter 135040, Minibatch Loss= 27.552231
# Training Accuracy= 0.98438
# Iter 135680, Minibatch Loss= 9.430206
# Training Accuracy= 0.98438
# Iter 136320, Minibatch Loss= 327.685547
# Training Accuracy= 0.93750
# Iter 136960, Minibatch Loss= 7.794189
# Training Accuracy= 0.98438
# Iter 137600, Minibatch Loss= 159.031357
# Training Accuracy= 0.95312
# Iter 138240, Minibatch Loss= 76.584229
# Training Accuracy= 0.98438
# Iter 138880, Minibatch Loss= 18.434235
# Training Accuracy= 0.98438
# Iter 139520, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 140160, Minibatch Loss= 76.463860
# Training Accuracy= 0.98438
# Iter 140800, Minibatch Loss= 89.250214
# Training Accuracy= 0.95312
# Iter 141440, Minibatch Loss= 1.244934
# Training Accuracy= 0.98438
# Iter 142080, Minibatch Loss= 14.704514
# Training Accuracy= 0.98438
# Iter 142720, Minibatch Loss= 15.990692
# Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 258.533936
# Training Accuracy= 0.92188
# Iter 144000, Minibatch Loss= 96.387207
# Training Accuracy= 0.95312
# Iter 144640, Minibatch Loss= 229.538437
# Training Accuracy= 0.96875
# Iter 145280, Minibatch Loss= 104.123795
# Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 112.130234
# Training Accuracy= 0.96875
# Iter 146560, Minibatch Loss= 46.162201
# Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 81.237671
# Training Accuracy= 0.98438
# Iter 147840, Minibatch Loss= 2.239258
# Training Accuracy= 0.98438
# Iter 148480, Minibatch Loss= 0.630188
# Training Accuracy= 0.98438
# Iter 149120, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 149760, Minibatch Loss= 290.664856
# Training Accuracy= 0.93750
# Iter 150400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 151040, Minibatch Loss= 112.701157
# Training Accuracy= 0.96875
# Iter 151680, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 152320, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 152960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 153600, Minibatch Loss= 243.589279
# Training Accuracy= 0.95312
# Iter 154240, Minibatch Loss= 86.591034
# Training Accuracy= 0.98438
# Iter 154880, Minibatch Loss= 334.567200
# Training Accuracy= 0.95312
# Iter 155520, Minibatch Loss= 55.129471
# Training Accuracy= 0.96875
# Iter 156160, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 156800, Minibatch Loss= 131.616241
# Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 14.009583
# Training Accuracy= 0.98438
# Iter 158080, Minibatch Loss= 17.631287
# Training Accuracy= 0.98438
# Iter 158720, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 159360, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 160000, Minibatch Loss= 52.447189
# Training Accuracy= 0.96875
# Iter 160640, Minibatch Loss= 21.064987
# Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 65.413956
# Training Accuracy= 0.98438
# Iter 161920, Minibatch Loss= 364.149017
# Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 163200, Minibatch Loss= 281.415558
# Training Accuracy= 0.98438
# Iter 163840, Minibatch Loss= 195.789993
# Training Accuracy= 0.98438
# Iter 164480, Minibatch Loss= 41.828522
# Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 153.234528
# Training Accuracy= 0.95312
# Iter 165760, Minibatch Loss= 6.295883
# Training Accuracy= 0.98438
# Iter 166400, Minibatch Loss= 320.305847
# Training Accuracy= 0.92188
# Iter 167040, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 167680, Minibatch Loss= 40.783798
# Training Accuracy= 0.96875
# Iter 168320, Minibatch Loss= 247.868118
# Training Accuracy= 0.98438
# Iter 168960, Minibatch Loss= 66.184021
# Training Accuracy= 0.98438
# Iter 169600, Minibatch Loss= 138.828827
# Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 170880, Minibatch Loss= 54.966629
# Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 70.893890
# Training Accuracy= 0.96875
# Iter 172160, Minibatch Loss= 20.155685
# Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 173440, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 174080, Minibatch Loss= 19.496750
# Training Accuracy= 0.96875
# Iter 174720, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 175360, Minibatch Loss= 310.799042
# Training Accuracy= 0.95312
# Iter 176000, Minibatch Loss= 212.673874
# Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 14.823753
# Training Accuracy= 0.98438
# Iter 177280, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 177920, Minibatch Loss= 11.254669
# Training Accuracy= 0.98438
# Iter 178560, Minibatch Loss= 28.540253
# Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 2.040512
# Training Accuracy= 0.98438
# Iter 179840, Minibatch Loss= 99.301773
# Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 3.902351
# Training Accuracy= 0.98438
# Iter 181120, Minibatch Loss= 17.683563
# Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 102.515335
# Training Accuracy= 0.95312
# Iter 182400, Minibatch Loss= 46.936356
# Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 139.091431
# Training Accuracy= 0.96875
# Iter 183680, Minibatch Loss= 74.367012
# Training Accuracy= 0.96875
# Iter 184320, Minibatch Loss= 19.270874
# Training Accuracy= 0.98438
# Iter 184960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 185600, Minibatch Loss= 102.329376
# Training Accuracy= 0.96875
# Iter 186240, Minibatch Loss= 0.127202
# Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 187520, Minibatch Loss= 99.387512
# Training Accuracy= 0.95312
# Iter 188160, Minibatch Loss= 187.762131
# Training Accuracy= 0.96875
# Iter 188800, Minibatch Loss= 125.079468
# Training Accuracy= 0.93750
# Iter 189440, Minibatch Loss= 37.412079
# Training Accuracy= 0.98438
# Iter 190080, Minibatch Loss= 134.813263
# Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 91.091675
# Training Accuracy= 0.96875
# Iter 191360, Minibatch Loss= 44.487045
# Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 25.279663
# Training Accuracy= 0.98438
# Iter 192640, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 193280, Minibatch Loss= 91.889420
# Training Accuracy= 0.96875
# Iter 193920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 194560, Minibatch Loss= 19.015085
# Training Accuracy= 0.98438
# Iter 195200, Minibatch Loss= 50.251694
# Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 47.802124
# Training Accuracy= 0.98438
# Iter 196480, Minibatch Loss= 50.914322
# Training Accuracy= 0.96875
# Iter 197120, Minibatch Loss= 121.418533
# Training Accuracy= 0.96875
# Iter 197760, Minibatch Loss= 250.061676
# Training Accuracy= 0.93750
# Iter 198400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 199040, Minibatch Loss= 0.398254
# Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 200320, Minibatch Loss= 14.319393
# Training Accuracy= 0.98438
# Iter 200960, Minibatch Loss= 162.186295
# Training Accuracy= 0.95312
# Iter 201600, Minibatch Loss= 168.898468
# Training Accuracy= 0.98438
# Iter 202240, Minibatch Loss= 357.448029
# Training Accuracy= 0.95312
# Iter 202880, Minibatch Loss= 2.580704
# Training Accuracy= 0.98438
# Iter 203520, Minibatch Loss= 47.697403
# Training Accuracy= 0.98438
# Iter 204160, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 204800, Minibatch Loss= 0.086640
# Training Accuracy= 0.98438
# Iter 205440, Minibatch Loss= 51.986816
# Training Accuracy= 0.98438
# Iter 206080, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 206720, Minibatch Loss= 262.633331
# Training Accuracy= 0.95312
# Iter 207360, Minibatch Loss= 65.950691
# Training Accuracy= 0.98438
# Iter 208000, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 208640, Minibatch Loss= 177.350220
# Training Accuracy= 0.95312
# Iter 209280, Minibatch Loss= 21.398613
# Training Accuracy= 0.96875
# Iter 209920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 210560, Minibatch Loss= 61.948101
# Training Accuracy= 0.98438
# Iter 211200, Minibatch Loss= 13.176865
# Training Accuracy= 0.98438
# Iter 211840, Minibatch Loss= 14.684448
# Training Accuracy= 0.98438
# Iter 212480, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 213120, Minibatch Loss= 18.123108
# Training Accuracy= 0.98438
# Iter 213760, Minibatch Loss= 28.490257
# Training Accuracy= 0.96875
# Iter 214400, Minibatch Loss= 24.329041
# Training Accuracy= 0.96875
# Iter 215040, Minibatch Loss= 19.228607
# Training Accuracy= 0.98438
# Iter 215680, Minibatch Loss= 40.198738
# Training Accuracy= 0.96875
# Iter 216320, Minibatch Loss= 50.056061
# Training Accuracy= 0.98438
# Iter 216960, Minibatch Loss= 4.943115
# Training Accuracy= 0.98438
# Iter 217600, Minibatch Loss= 28.258392
# Training Accuracy= 0.98438
# Iter 218240, Minibatch Loss= 98.194908
# Training Accuracy= 0.96875
# Iter 218880, Minibatch Loss= 45.715530
# Training Accuracy= 0.96875
# Iter 219520, Minibatch Loss= 73.778488
# Training Accuracy= 0.96875
# Iter 220160, Minibatch Loss= 124.550385
# Training Accuracy= 0.96875
# Iter 220800, Minibatch Loss= 42.707031
# Training Accuracy= 0.98438
# Iter 221440, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 222080, Minibatch Loss= 24.126785
# Training Accuracy= 0.98438
# Iter 222720, Minibatch Loss= 33.394501
# Training Accuracy= 0.98438
# Iter 223360, Minibatch Loss= 77.699036
# Training Accuracy= 0.95312
# Iter 224000, Minibatch Loss= 39.582382
# Training Accuracy= 0.98438
# Iter 224640, Minibatch Loss= 127.244301
# Training Accuracy= 0.96875
# Iter 225280, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 225920, Minibatch Loss= 36.837708
# Training Accuracy= 0.98438
# Iter 226560, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 227200, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 227840, Minibatch Loss= 42.530396
# Training Accuracy= 0.98438
# Iter 228480, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 229120, Minibatch Loss= 83.982567
# Training Accuracy= 0.96875
# Iter 229760, Minibatch Loss= 7.203583
# Training Accuracy= 0.98438
# Iter 230400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 231040, Minibatch Loss= 19.310776
# Training Accuracy= 0.98438
# Iter 231680, Minibatch Loss= 119.724457
# Training Accuracy= 0.95312
# Iter 232320, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 232960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 82.066956
# Training Accuracy= 0.95312
# Iter 234240, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 234880, Minibatch Loss= 13.518837
# Training Accuracy= 0.96875
# Iter 235520, Minibatch Loss= 91.929749
# Training Accuracy= 0.98438
# Iter 236160, Minibatch Loss= 39.515076
# Training Accuracy= 0.96875
# Iter 236800, Minibatch Loss= 2.559204
# Training Accuracy= 0.98438
# Iter 237440, Minibatch Loss= 3.271881
# Training Accuracy= 0.98438
# Iter 238080, Minibatch Loss= 10.272583
# Training Accuracy= 0.98438
# Iter 238720, Minibatch Loss= 59.324722
# Training Accuracy= 0.98438
# Iter 239360, Minibatch Loss= 129.396057
# Training Accuracy= 0.95312
# Iter 240000, Minibatch Loss= 53.604813
# Training Accuracy= 0.98438
# Iter 240640, Minibatch Loss= 138.312439
# Training Accuracy= 0.93750
# Iter 241280, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 241920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 242560, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 243200, Minibatch Loss= 7.462448
# Training Accuracy= 0.98438
# Iter 243840, Minibatch Loss= 57.928497
# Training Accuracy= 0.98438
# Iter 244480, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 245120, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 245760, Minibatch Loss= 45.023895
# Training Accuracy= 0.96875
# Iter 246400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 247040, Minibatch Loss= 20.580460
# Training Accuracy= 0.98438
# Iter 247680, Minibatch Loss= 44.226639
# Training Accuracy= 0.98438
# Iter 248320, Minibatch Loss= 42.341583
# Training Accuracy= 0.95312
# Iter 248960, Minibatch Loss= 62.829887
# Training Accuracy= 0.98438
# Iter 249600, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 250240, Minibatch Loss= 67.883118
# Training Accuracy= 0.98438
# Iter 250880, Minibatch Loss= 166.714050
# Training Accuracy= 0.93750
# Iter 251520, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 252160, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 252800, Minibatch Loss= 117.434570
# Training Accuracy= 0.93750
# Iter 253440, Minibatch Loss= 49.007248
# Training Accuracy= 0.95312
# Iter 254080, Minibatch Loss= 15.797379
# Training Accuracy= 0.98438
# Iter 254720, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 255360, Minibatch Loss= 71.597473
# Training Accuracy= 0.96875
# Iter 256000, Minibatch Loss= 52.343685
# Training Accuracy= 0.96875
# Iter 256640, Minibatch Loss= 11.998749
# Training Accuracy= 0.98438
# Iter 257280, Minibatch Loss= 36.328621
# Training Accuracy= 0.98438
# Iter 257920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 258560, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 259200, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 259840, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 260480, Minibatch Loss= 105.407623
# Training Accuracy= 0.98438
# Iter 261120, Minibatch Loss= 81.443054
# Training Accuracy= 0.98438
# Iter 261760, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 113.213882
# Training Accuracy= 0.96875
# Iter 263040, Minibatch Loss= 42.714340
# Training Accuracy= 0.98438
# Iter 263680, Minibatch Loss= 24.263428
# Training Accuracy= 0.98438
# Iter 264320, Minibatch Loss= 6.917755
# Training Accuracy= 0.98438
# Iter 264960, Minibatch Loss= 85.640732
# Training Accuracy= 0.96875
# Iter 265600, Minibatch Loss= 13.126022
# Training Accuracy= 0.98438
# Iter 266240, Minibatch Loss= 116.145760
# Training Accuracy= 0.98438
# Iter 266880, Minibatch Loss= 38.798706
# Training Accuracy= 0.96875
# Iter 267520, Minibatch Loss= 66.167831
# Training Accuracy= 0.98438
# Iter 268160, Minibatch Loss= 3.022781
# Training Accuracy= 0.98438
# Iter 268800, Minibatch Loss= 145.815491
# Training Accuracy= 0.98438
# Iter 269440, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 270080, Minibatch Loss= 43.146126
# Training Accuracy= 0.98438
# Iter 270720, Minibatch Loss= 55.814255
# Training Accuracy= 0.95312
# Iter 271360, Minibatch Loss= 1.418732
# Training Accuracy= 0.98438
# Iter 272000, Minibatch Loss= 34.626740
# Training Accuracy= 0.98438
# Iter 272640, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 273280, Minibatch Loss= 3.622604
# Training Accuracy= 0.98438
# Iter 273920, Minibatch Loss= 29.330811
# Training Accuracy= 0.98438
# Iter 274560, Minibatch Loss= 57.998596
# Training Accuracy= 0.98438
# Iter 275200, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 275840, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 276480, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 277120, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 277760, Minibatch Loss= 29.555405
# Training Accuracy= 0.96875
# Iter 278400, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 279040, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 279680, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 280320, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 280960, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 281600, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 282240, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 282880, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 283520, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 284160, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 284800, Minibatch Loss= 21.489334
# Training Accuracy= 0.96875
# Iter 285440, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 286080, Minibatch Loss= 0.103102
# Training Accuracy= 0.98438
# Iter 286720, Minibatch Loss= 16.243912
# Training Accuracy= 0.98438
# Iter 287360, Minibatch Loss= 19.349136
# Training Accuracy= 0.98438
# Iter 288000, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 288640, Minibatch Loss= 47.477829
# Training Accuracy= 0.98438
# Iter 289280, Minibatch Loss= 53.604210
# Training Accuracy= 0.98438
# Iter 289920, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 290560, Minibatch Loss= 29.474121
# Training Accuracy= 0.98438
# Iter 291200, Minibatch Loss= 0.330948
# Training Accuracy= 0.98438
# Iter 291840, Minibatch Loss= 60.666443
# Training Accuracy= 0.98438
# Iter 292480, Minibatch Loss= 19.233620
# Training Accuracy= 0.98438
# Iter 293120, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 293760, Minibatch Loss= 8.384308
# Training Accuracy= 0.98438
# Iter 294400, Minibatch Loss= 39.625000
# Training Accuracy= 0.98438
# Iter 295040, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 295680, Minibatch Loss= 8.263954
# Training Accuracy= 0.98438
# Iter 296320, Minibatch Loss= 5.628082
# Training Accuracy= 0.98438
# Iter 296960, Minibatch Loss= 83.579071
# Training Accuracy= 0.98438
# Iter 297600, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 298240, Minibatch Loss= 0.000000
# Training Accuracy= 1.00000
# Iter 298880, Minibatch Loss= 63.735146
# Training Accuracy= 0.98438
# Iter 299520, Minibatch Loss= 90.870827
# Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 1.0

# %%
ret1 = np.array(D1).transpose()
ret2 = np.array(D2).transpose()
ret3 = np.array(L).transpose()

# %%
labels = ['majoritypool-maxpool', 'weightedmaxpool-maxpool', 
          'weightedmajoritypool-maxpool', 'maxpoolweighted-maxpool', 
          'majoritypoolweighted-maxpool', 'pcapool-maxpool']
plt.figure(figsize=(15,10))
for i in range(6):
    plt.plot(range(ret1.shape[1]), ret1[i])
plt.legend(labels, loc='lower right', prop={'size':15})
plt.ylabel('Difference')
plt.xlabel('Iteration')
plt.show()

# %%
labels = ['majoritypool-maxpool', 'weightedmaxpool-maxpool', 
          'weightedmajoritypool-maxpool', 'maxpoolweighted-maxpool', 
          'majoritypoolweighted-maxpool', 'pcapool-maxpool']
plt.figure(figsize=(15,10))
for i in range(6):
    plt.plot(range(ret2.shape[1]), ret2[i])
plt.legend(labels, loc='lower right', prop={'size':15})
plt.ylabel('Difference')
plt.xlabel('Iteration')
plt.show()

# %%
labels = ['maxpooling', 'majoritypool', 'weightedmaxpool', 
          'weightedmajoritypool', 'maxpoolweighted', 
          'majoritypoolweighted', 'pcapool']
plt.figure(figsize=(15,10))
for i in range(6):
    plt.plot(range(ret3.shape[1]), ret3[i])
plt.legend(labels, loc='upper right', prop={'size':15})
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.show()
