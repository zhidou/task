# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.nan)
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding = 'SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

# extract patches from feature maps
# input shape N, H, W, C
# output shape N, H, W, K, C
def extract_patches(x, padding, ksize=2, stride=2):
    temp = tf.extract_image_patches(images=x, ksizes=[1, ksize, ksize, 1], strides=[1, stride, stride, 1], rates=[1,1,1,1], padding=padding)
    [N, H, W, C] = temp.get_shape().as_list()
    C = x.get_shape().as_list()[-1]
#     reshape to N,H,W,K,C
    temp = tf.reshape(temp, [-1, H, W, ksize*ksize, C])
    return temp
# MaxPool
def max_pool(p):
    return tf.reduce_max(p, axis=3)

# %%
# pcaPool
# if m == 1, then consider each window as an unique instances, and each window have their own pca encoder
# if m != 1, then all windows fetch from the same feature map share one pca encoder
def pca_pool(temp, m = 1):
    [N, H, W, K, C] = temp.get_shape().as_list()
    if m == 1:
        temp = tf.transpose(temp, [0,1,2,4,3])
        temp = tf.reshape(temp, [-1, K, 1])
    else:
        temp = tf.transpose(temp, [0,4,3,1,2])
        temp = tf.reshape(temp, [-1, K, H*W])
#     compute for svd
    [s, u, v] = tf.svd(tf.matmul(temp, tf.transpose(temp, [0,2,1])), compute_uv=True)
#     use mark to remove Eigenvector except for the first one, which is the main component
    temp_mark = np.zeros([K,K])
    temp_mark[:,0] = 1
    mark = tf.constant(temp_mark, dtype=tf.float32)
    
#     after reduce_sum actually it has been transposed automatically
    u = tf.reduce_sum(tf.multiply(u, mark), axis=2)
    u = tf.reshape(u, [-1, 1, K])
    
    temp = tf.matmul(u, temp)/np.sqrt(K)
    if m == 1: temp = tf.reshape(temp, [-1, H, W, C])
    else: 
        temp = tf.reshape(temp, [-1, C, H, W])
        temp = tf.transpose(temp, [0, 2, 3, 1])
    return temp

# %%
# compute the frequency of element in each patch
# input extracted patches tensor in shape N, H, W, K, C
# output frequency tensor in shape N, H, W, K, C
def majority_frequency(temp):
    [N, H, W, K, C] = temp.get_shape().as_list()
    print([N, H, W, K, C])
    temp = tf.to_int32(tf.round(temp))
#     build one hot vector
    temp = tf.transpose(temp, [0,1,2,4,3])
    one_hot = tf.one_hot(indices=temp, depth=tf.reduce_max(temp) + 1, dtype=tf.float32)
#     the dimension is bathch, row, col, lay, one hot
#     the order tensorflow takes, when doiong transpose, it will from the most right to most left
    one_hot = tf.reduce_sum(one_hot, axis=4)
    temp = tf.transpose(temp, [0, 3, 1, 2, 4])
    temp = tf.reshape(temp, [N*H*W*C*K,1])
    one_hot = tf.transpose(one_hot, [0,3,1,2,4])
    one_hot = tf.reshape(one_hot, [N*H*W*C, -1])
    
    index = tf.constant(np.array([range(temp.get_shape().as_list()[0])])/ K, dtype=tf.int32)
    temp = tf.concat((tf.transpose(index), temp), axis=1)
    
#     to get the percentage
    temp = tf.gather_nd(one_hot, temp)
    temp = tf.reshape(temp, [N, C, H, W, K])
#     finally we change it back to N,H,W,K,C
    temp = tf.transpose(temp, [0, 2, 3, 4, 1])
    return temp

def majority_pool(p, f):
    btemp = tf.reduce_max(f , axis=[3], keep_dims=True)
#     get the index of the majority element
    temp = tf.equal(f, btemp)
    temp = tf.to_float(temp)
#     use the largest frequency to represent each window
    btemp = tf.squeeze(btemp, squeeze_dims=3)
#     compute mean of the elements that have same round value in each window
    temp = tf.divide(tf.reduce_sum(tf.multiply(p, temp), axis=[3]), btemp)
#     when the largest frequency is 1, then we just the max value in p as the result, else use the mean of the of elements
#     having the same round value, as the result.
    temp = tf.where(tf.equal(btemp, 1), 
                    tf.reduce_max(p, axis=[3]), temp)
    return temp

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 64
display_step = 10

# %%
# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    
    x = tf.reshape(x, shape=[64, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    p = extract_patches(conv1, 'SAME', 2, 2)
    f = majority_frequency(p)
    temp = majority_pool(p, f)
#     temp = max_pool(p)
    
    # Convolution Layer
    conv2 = conv2d(temp, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    p = extract_patches(conv2, 'SAME', 2, 2)
    f = majority_frequency(p)
    temp = majority_pool(p, f)
#     temp = max_pool(p)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(temp, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return conv1, out

# %%
# Construct model
conv1, pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# [64, 14, 14, 4, 32]
# [64, 7, 7, 4, 64]

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
#     while step < 2:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        ret = sess.run(conv1, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + 
                  "\nTraining Accuracy= " + "{:.5f}".format(acc))
        step += 1
        with open('output.txt', 'a') as f:
            f.write('\nmaxpooling value: \n')
        with open('output.txt', 'a') as f:
        #             np.savetxt(f, np.amax(ret), delimiter=', ',fmt="%.2f")
            f.write(str(np.amax(ret)))
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:64], y: mnist.test.labels[:64],
keep_prob: 1.}))
# Out:
# Iter 640, Minibatch Loss= 27102.486328
# Training Accuracy= 0.21875
# Iter 1280, Minibatch Loss= 16662.992188
# Training Accuracy= 0.28125
# Iter 1920, Minibatch Loss= 11796.603516
# Training Accuracy= 0.37500
# Iter 2560, Minibatch Loss= 8583.090820
# Training Accuracy= 0.57812
# Iter 3200, Minibatch Loss= 8185.166016
# Training Accuracy= 0.59375
# Iter 3840, Minibatch Loss= 6372.175781
# Training Accuracy= 0.67188
# Iter 4480, Minibatch Loss= 5220.750977
# Training Accuracy= 0.64062
# Iter 5120, Minibatch Loss= 3244.526611
# Training Accuracy= 0.71875
# Iter 5760, Minibatch Loss= 5117.715820
# Training Accuracy= 0.67188
# Iter 6400, Minibatch Loss= 2847.759277
# Training Accuracy= 0.78125
# Iter 7040, Minibatch Loss= 4150.369629
# Training Accuracy= 0.76562
# Iter 7680, Minibatch Loss= 3805.197754
# Training Accuracy= 0.81250
# Iter 8320, Minibatch Loss= 4788.616211
# Training Accuracy= 0.70312
# Iter 8960, Minibatch Loss= 2634.083740
# Training Accuracy= 0.75000
# Iter 9600, Minibatch Loss= 3271.806641
# Training Accuracy= 0.70312
# Iter 10240, Minibatch Loss= 4861.062988
# Training Accuracy= 0.71875
# Iter 10880, Minibatch Loss= 3590.685059
# Training Accuracy= 0.81250
# Iter 11520, Minibatch Loss= 3323.123535
# Training Accuracy= 0.78125
# Iter 12160, Minibatch Loss= 1350.242188
# Training Accuracy= 0.85938
# Iter 12800, Minibatch Loss= 3962.549316
# Training Accuracy= 0.79688
# Iter 13440, Minibatch Loss= 2005.226562
# Training Accuracy= 0.84375
# Iter 14080, Minibatch Loss= 1792.525391
# Training Accuracy= 0.79688
# Iter 14720, Minibatch Loss= 4014.560547
# Training Accuracy= 0.79688
# Iter 15360, Minibatch Loss= 2078.873535
# Training Accuracy= 0.85938
# Iter 16000, Minibatch Loss= 2360.264160
# Training Accuracy= 0.79688
# Iter 16640, Minibatch Loss= 967.821533
# Training Accuracy= 0.84375
# Iter 17280, Minibatch Loss= 3259.833008
# Training Accuracy= 0.81250
# Iter 17920, Minibatch Loss= 1781.750000
# Training Accuracy= 0.82812
# Iter 18560, Minibatch Loss= 1234.368408
# Training Accuracy= 0.87500
# Iter 19200, Minibatch Loss= 1733.809570
# Training Accuracy= 0.87500
# Iter 19840, Minibatch Loss= 1676.274292
# Training Accuracy= 0.81250
# Iter 20480, Minibatch Loss= 2072.052246
# Training Accuracy= 0.81250
# Iter 21120, Minibatch Loss= 1874.300781
# Training Accuracy= 0.85938
# Iter 21760, Minibatch Loss= 783.516724
# Training Accuracy= 0.85938
# Iter 22400, Minibatch Loss= 1387.055664
# Training Accuracy= 0.85938
# Iter 23040, Minibatch Loss= 2093.160645
# Training Accuracy= 0.79688
# Iter 23680, Minibatch Loss= 1624.788086
# Training Accuracy= 0.82812
# Iter 24320, Minibatch Loss= 843.893311
# Training Accuracy= 0.89062
# Iter 24960, Minibatch Loss= 2090.092285
# Training Accuracy= 0.84375
# Iter 25600, Minibatch Loss= 1187.344116
# Training Accuracy= 0.76562
# Iter 26240, Minibatch Loss= 627.923950
# Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 1292.627441
# Training Accuracy= 0.84375
# Iter 27520, Minibatch Loss= 1174.448486
# Training Accuracy= 0.82812
# Iter 28160, Minibatch Loss= 1263.778198
# Training Accuracy= 0.85938
# Iter 28800, Minibatch Loss= 1136.529663
# Training Accuracy= 0.89062
# Iter 29440, Minibatch Loss= 1867.304688
# Training Accuracy= 0.87500
# Iter 30080, Minibatch Loss= 758.449097
# Training Accuracy= 0.84375
# Iter 30720, Minibatch Loss= 1511.852539
# Training Accuracy= 0.79688
# Iter 31360, Minibatch Loss= 670.725342
# Training Accuracy= 0.92188
# Iter 32000, Minibatch Loss= 677.881226
# Training Accuracy= 0.85938
# Iter 32640, Minibatch Loss= 707.033142
# Training Accuracy= 0.84375
# Iter 33280, Minibatch Loss= 1388.272217
# Training Accuracy= 0.89062
# Iter 33920, Minibatch Loss= 895.875610
# Training Accuracy= 0.92188
# Iter 34560, Minibatch Loss= 1471.381104
# Training Accuracy= 0.89062
# Iter 35200, Minibatch Loss= 898.732666
# Training Accuracy= 0.85938
# Iter 35840, Minibatch Loss= 1014.698608
# Training Accuracy= 0.89062
# Iter 36480, Minibatch Loss= 1111.062134
# Training Accuracy= 0.87500
# Iter 37120, Minibatch Loss= 591.403870
# Training Accuracy= 0.89062
# Iter 37760, Minibatch Loss= 882.765869
# Training Accuracy= 0.84375
# Iter 38400, Minibatch Loss= 1335.080566
# Training Accuracy= 0.87500
# Iter 39040, Minibatch Loss= 1009.490479
# Training Accuracy= 0.87500
# Iter 39680, Minibatch Loss= 519.270691
# Training Accuracy= 0.90625
# Iter 40320, Minibatch Loss= 1119.094971
# Training Accuracy= 0.85938
# Iter 40960, Minibatch Loss= 611.780029
# Training Accuracy= 0.92188
# Iter 41600, Minibatch Loss= 875.557434
# Training Accuracy= 0.81250
# Iter 42240, Minibatch Loss= 834.021729
# Training Accuracy= 0.92188
# Iter 42880, Minibatch Loss= 1054.986206
# Training Accuracy= 0.89062
# Iter 43520, Minibatch Loss= 139.582443
# Training Accuracy= 0.96875
# Iter 44160, Minibatch Loss= 378.849792
# Training Accuracy= 0.92188
# Iter 44800, Minibatch Loss= 353.536438
# Training Accuracy= 0.92188
# Iter 45440, Minibatch Loss= 1072.434326
# Training Accuracy= 0.84375
# Iter 46080, Minibatch Loss= 460.811646
# Training Accuracy= 0.90625
# Iter 46720, Minibatch Loss= 563.485901
# Training Accuracy= 0.87500
# Iter 47360, Minibatch Loss= 639.152100
# Training Accuracy= 0.90625
# Iter 48000, Minibatch Loss= 399.893463
# Training Accuracy= 0.92188
# Iter 48640, Minibatch Loss= 1005.126221
# Training Accuracy= 0.84375
# Iter 49280, Minibatch Loss= 828.146362
# Training Accuracy= 0.89062
# Iter 49920, Minibatch Loss= 610.923218
# Training Accuracy= 0.89062
# Iter 50560, Minibatch Loss= 863.302734
# Training Accuracy= 0.87500
# Iter 51200, Minibatch Loss= 513.156799
# Training Accuracy= 0.89062
# Iter 51840, Minibatch Loss= 205.732162
# Training Accuracy= 0.93750
# Iter 52480, Minibatch Loss= 263.313416
# Training Accuracy= 0.95312
# Iter 53120, Minibatch Loss= 824.484497
# Training Accuracy= 0.84375
# Iter 53760, Minibatch Loss= 942.679138
# Training Accuracy= 0.81250
# Iter 54400, Minibatch Loss= 717.637573
# Training Accuracy= 0.89062
# Iter 55040, Minibatch Loss= 698.911743
# Training Accuracy= 0.85938
# Iter 55680, Minibatch Loss= 517.569397
# Training Accuracy= 0.90625
# Iter 56320, Minibatch Loss= 491.466095
# Training Accuracy= 0.90625
# Iter 56960, Minibatch Loss= 1071.457031
# Training Accuracy= 0.87500
# Iter 57600, Minibatch Loss= 179.085556
# Training Accuracy= 0.89062
# Iter 58240, Minibatch Loss= 574.642944
# Training Accuracy= 0.90625
# Iter 58880, Minibatch Loss= 848.487549
# Training Accuracy= 0.84375
# Iter 59520, Minibatch Loss= 731.155396
# Training Accuracy= 0.89062
# Iter 60160, Minibatch Loss= 1345.827881
# Training Accuracy= 0.78125
# Iter 60800, Minibatch Loss= 138.722733
# Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 504.781250
# Training Accuracy= 0.90625
# Iter 62080, Minibatch Loss= 1015.629272
# Training Accuracy= 0.82812
# Iter 62720, Minibatch Loss= 333.050446
# Training Accuracy= 0.93750
# Iter 63360, Minibatch Loss= 628.265747
# Training Accuracy= 0.89062
# Iter 64000, Minibatch Loss= 1166.223511
# Training Accuracy= 0.82812
# Iter 64640, Minibatch Loss= 438.559723
# Training Accuracy= 0.87500
# Iter 65280, Minibatch Loss= 205.747314
# Training Accuracy= 0.93750
# Iter 65920, Minibatch Loss= 889.116943
# Training Accuracy= 0.84375
# Iter 66560, Minibatch Loss= 905.531494
# Training Accuracy= 0.90625
# Iter 67200, Minibatch Loss= 440.444275
# Training Accuracy= 0.89062
# Iter 67840, Minibatch Loss= 1164.646606
# Training Accuracy= 0.85938
# Iter 68480, Minibatch Loss= 470.465790
# Training Accuracy= 0.89062
# Iter 69120, Minibatch Loss= 148.575867
# Training Accuracy= 0.92188
# Iter 69760, Minibatch Loss= 407.945374
# Training Accuracy= 0.84375
# Iter 70400, Minibatch Loss= 250.130692
# Training Accuracy= 0.96875
# Iter 71040, Minibatch Loss= 565.839722
# Training Accuracy= 0.84375
# Iter 71680, Minibatch Loss= 491.189636
# Training Accuracy= 0.90625
# Iter 72320, Minibatch Loss= 279.565857
# Training Accuracy= 0.90625
# Iter 72960, Minibatch Loss= 203.017288
# Training Accuracy= 0.89062
# Iter 73600, Minibatch Loss= 855.416321
# Training Accuracy= 0.90625
# Iter 74240, Minibatch Loss= 365.227112
# Training Accuracy= 0.87500
# Iter 74880, Minibatch Loss= 639.522400
# Training Accuracy= 0.82812
# Iter 75520, Minibatch Loss= 1140.943604
# Training Accuracy= 0.82812
# Iter 76160, Minibatch Loss= 232.101822
# Training Accuracy= 0.92188
# Iter 76800, Minibatch Loss= 284.319611
# Training Accuracy= 0.92188
# Iter 77440, Minibatch Loss= 356.803772
# Training Accuracy= 0.92188
# Iter 78080, Minibatch Loss= 247.014359
# Training Accuracy= 0.92188
# Iter 78720, Minibatch Loss= 673.570068
# Training Accuracy= 0.85938
# Iter 79360, Minibatch Loss= 419.833771
# Training Accuracy= 0.93750
# Iter 80000, Minibatch Loss= 226.807968
# Training Accuracy= 0.90625
# Iter 80640, Minibatch Loss= 318.375549
# Training Accuracy= 0.87500
# Iter 81280, Minibatch Loss= 503.556030
# Training Accuracy= 0.89062
# Iter 81920, Minibatch Loss= 547.062866
# Training Accuracy= 0.79688
# Iter 82560, Minibatch Loss= 278.093658
# Training Accuracy= 0.92188
# Iter 83200, Minibatch Loss= 219.269684
# Training Accuracy= 0.93750
# Iter 83840, Minibatch Loss= 204.761444
# Training Accuracy= 0.90625
# Iter 84480, Minibatch Loss= 398.532654
# Training Accuracy= 0.87500
# Iter 85120, Minibatch Loss= 112.931953
# Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 191.436707
# Training Accuracy= 0.90625
# Iter 86400, Minibatch Loss= 397.462860
# Training Accuracy= 0.87500
# Iter 87040, Minibatch Loss= 482.415649
# Training Accuracy= 0.89062
# Iter 87680, Minibatch Loss= 274.105347
# Training Accuracy= 0.90625
# Iter 88320, Minibatch Loss= 255.661591
# Training Accuracy= 0.89062
# Iter 88960, Minibatch Loss= 364.209595
# Training Accuracy= 0.90625
# Iter 89600, Minibatch Loss= 280.923340
# Training Accuracy= 0.87500
# Iter 90240, Minibatch Loss= 252.202530
# Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 360.904205
# Training Accuracy= 0.92188
# Iter 91520, Minibatch Loss= 379.481873
# Training Accuracy= 0.84375
# Iter 92160, Minibatch Loss= 208.149765
# Training Accuracy= 0.93750
# Iter 92800, Minibatch Loss= 94.117104
# Training Accuracy= 0.93750
# Iter 93440, Minibatch Loss= 312.281067
# Training Accuracy= 0.85938
# Iter 94080, Minibatch Loss= 667.615479
# Training Accuracy= 0.81250
# Iter 94720, Minibatch Loss= 183.633316
# Training Accuracy= 0.92188
# Iter 95360, Minibatch Loss= 30.485027
# Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 443.649628
# Training Accuracy= 0.89062
# Iter 96640, Minibatch Loss= 152.117554
# Training Accuracy= 0.90625
# Iter 97280, Minibatch Loss= 308.445343
# Training Accuracy= 0.92188
# Iter 97920, Minibatch Loss= 525.521667
# Training Accuracy= 0.85938
# Iter 98560, Minibatch Loss= 149.277893
# Training Accuracy= 0.92188
# Iter 99200, Minibatch Loss= 310.427002
# Training Accuracy= 0.92188
# Iter 99840, Minibatch Loss= 825.840637
# Training Accuracy= 0.78125
# Iter 100480, Minibatch Loss= 367.419067
# Training Accuracy= 0.84375
# Iter 101120, Minibatch Loss= 305.374817
# Training Accuracy= 0.89062
# Iter 101760, Minibatch Loss= 333.997253
# Training Accuracy= 0.84375
# Iter 102400, Minibatch Loss= 273.113892
# Training Accuracy= 0.90625
# Iter 103040, Minibatch Loss= 318.048706
# Training Accuracy= 0.87500
# Iter 103680, Minibatch Loss= 155.824417
# Training Accuracy= 0.90625
# Iter 104320, Minibatch Loss= 91.473999
# Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 618.676392
# Training Accuracy= 0.87500
# Iter 105600, Minibatch Loss= 268.672211
# Training Accuracy= 0.89062
# Iter 106240, Minibatch Loss= 501.632416
# Training Accuracy= 0.87500
# Iter 106880, Minibatch Loss= 256.797668
# Training Accuracy= 0.90625
# Iter 107520, Minibatch Loss= 479.645752
# Training Accuracy= 0.87500
# Iter 108160, Minibatch Loss= 322.843323
# Training Accuracy= 0.89062
# Iter 108800, Minibatch Loss= 296.044312
# Training Accuracy= 0.90625
# Iter 109440, Minibatch Loss= 254.352478
# Training Accuracy= 0.89062
# Iter 110080, Minibatch Loss= 387.970215
# Training Accuracy= 0.89062
# Iter 110720, Minibatch Loss= 183.842438
# Training Accuracy= 0.87500
# Iter 111360, Minibatch Loss= 205.745544
# Training Accuracy= 0.87500
# Iter 112000, Minibatch Loss= 325.350220
# Training Accuracy= 0.92188
# Iter 112640, Minibatch Loss= 264.650940
# Training Accuracy= 0.87500
# Iter 113280, Minibatch Loss= 179.473297
# Training Accuracy= 0.87500
# Iter 113920, Minibatch Loss= 152.861069
# Training Accuracy= 0.93750
# Iter 114560, Minibatch Loss= 212.516388
# Training Accuracy= 0.89062
# Iter 115200, Minibatch Loss= 240.527985
# Training Accuracy= 0.90625
# Iter 115840, Minibatch Loss= 220.495865
# Training Accuracy= 0.87500
# Iter 116480, Minibatch Loss= 75.590805
# Training Accuracy= 0.93750
# Iter 117120, Minibatch Loss= 179.109314
# Training Accuracy= 0.92188
# Iter 117760, Minibatch Loss= 88.188995
# Training Accuracy= 0.93750
# Iter 118400, Minibatch Loss= 187.228851
# Training Accuracy= 0.95312
# Iter 119040, Minibatch Loss= 279.618103
# Training Accuracy= 0.87500
# Iter 119680, Minibatch Loss= 276.498352
# Training Accuracy= 0.90625
# Iter 120320, Minibatch Loss= 117.198975
# Training Accuracy= 0.90625
# Iter 120960, Minibatch Loss= 914.008972
# Training Accuracy= 0.78125
# Iter 121600, Minibatch Loss= 162.973969
# Training Accuracy= 0.90625
# Iter 122240, Minibatch Loss= 143.378128
# Training Accuracy= 0.92188
# Iter 122880, Minibatch Loss= 260.162140
# Training Accuracy= 0.87500
# Iter 123520, Minibatch Loss= 118.151207
# Training Accuracy= 0.95312
# Iter 124160, Minibatch Loss= 151.824554
# Training Accuracy= 0.92188
# Iter 124800, Minibatch Loss= 143.662262
# Training Accuracy= 0.95312
# Iter 125440, Minibatch Loss= 434.026550
# Training Accuracy= 0.85938
# Iter 126080, Minibatch Loss= 267.973175
# Training Accuracy= 0.93750
# Iter 126720, Minibatch Loss= 386.834137
# Training Accuracy= 0.78125
# Iter 127360, Minibatch Loss= 142.732605
# Training Accuracy= 0.92188
# Iter 128000, Minibatch Loss= 24.773617
# Training Accuracy= 0.95312
# Iter 128640, Minibatch Loss= 254.062256
# Training Accuracy= 0.89062
# Iter 129280, Minibatch Loss= 341.326538
# Training Accuracy= 0.89062
# Iter 129920, Minibatch Loss= 191.831848
# Training Accuracy= 0.92188
# Iter 130560, Minibatch Loss= 289.041077
# Training Accuracy= 0.90625
# Iter 131200, Minibatch Loss= 306.284698
# Training Accuracy= 0.90625
# Iter 131840, Minibatch Loss= 335.164734
# Training Accuracy= 0.85938
# Iter 132480, Minibatch Loss= 89.484825
# Training Accuracy= 0.93750
# Iter 133120, Minibatch Loss= 248.102280
# Training Accuracy= 0.92188
# Iter 133760, Minibatch Loss= 378.060974
# Training Accuracy= 0.87500
# Iter 134400, Minibatch Loss= 250.185684
# Training Accuracy= 0.90625
# Iter 135040, Minibatch Loss= 394.746460
# Training Accuracy= 0.81250
# Iter 135680, Minibatch Loss= 279.694153
# Training Accuracy= 0.89062
# Iter 136320, Minibatch Loss= 69.875916
# Training Accuracy= 0.95312
# Iter 136960, Minibatch Loss= 271.125793
# Training Accuracy= 0.87500
# Iter 137600, Minibatch Loss= 624.159180
# Training Accuracy= 0.81250
# Iter 138240, Minibatch Loss= 314.259003
# Training Accuracy= 0.89062
# Iter 138880, Minibatch Loss= 254.028275
# Training Accuracy= 0.89062
# Iter 139520, Minibatch Loss= 72.613144
# Training Accuracy= 0.90625
# Iter 140160, Minibatch Loss= 325.040588
# Training Accuracy= 0.87500
# Iter 140800, Minibatch Loss= 379.596222
# Training Accuracy= 0.82812
# Iter 141440, Minibatch Loss= 261.744598
# Training Accuracy= 0.89062
# Iter 142080, Minibatch Loss= 161.659256
# Training Accuracy= 0.87500
# Iter 142720, Minibatch Loss= 129.203644
# Training Accuracy= 0.95312
# Iter 143360, Minibatch Loss= 290.886810
# Training Accuracy= 0.87500
# Iter 144000, Minibatch Loss= 131.516342
# Training Accuracy= 0.92188
# Iter 144640, Minibatch Loss= 0.057022
# Training Accuracy= 0.98438
# Iter 145280, Minibatch Loss= 237.471954
# Training Accuracy= 0.89062
# Iter 145920, Minibatch Loss= 431.305298
# Training Accuracy= 0.82812
# Iter 146560, Minibatch Loss= 156.533508
# Training Accuracy= 0.89062
# Iter 147200, Minibatch Loss= 264.707275
# Training Accuracy= 0.81250
# Iter 147840, Minibatch Loss= 24.244183
# Training Accuracy= 0.95312
# Iter 148480, Minibatch Loss= 393.977661
# Training Accuracy= 0.85938
# Iter 149120, Minibatch Loss= 172.563400
# Training Accuracy= 0.89062
# Iter 149760, Minibatch Loss= 229.696106
# Training Accuracy= 0.89062
# Iter 150400, Minibatch Loss= 86.509438
# Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 105.376900
# Training Accuracy= 0.93750
# Iter 151680, Minibatch Loss= 130.858521
# Training Accuracy= 0.89062
# Iter 152320, Minibatch Loss= 181.667267
# Training Accuracy= 0.89062
# Iter 152960, Minibatch Loss= 392.784973
# Training Accuracy= 0.87500
# Iter 153600, Minibatch Loss= 360.119232
# Training Accuracy= 0.90625
# Iter 154240, Minibatch Loss= 161.847794
# Training Accuracy= 0.87500
# Iter 154880, Minibatch Loss= 252.262573
# Training Accuracy= 0.89062
# Iter 155520, Minibatch Loss= 328.194458
# Training Accuracy= 0.81250
# Iter 156160, Minibatch Loss= 71.774460
# Training Accuracy= 0.90625
# Iter 156800, Minibatch Loss= 201.451355
# Training Accuracy= 0.84375
# Iter 157440, Minibatch Loss= 84.896126
# Training Accuracy= 0.92188
# Iter 158080, Minibatch Loss= 221.709534
# Training Accuracy= 0.87500
# Iter 158720, Minibatch Loss= 149.010178
# Training Accuracy= 0.87500
# Iter 159360, Minibatch Loss= 87.766090
# Training Accuracy= 0.89062
# Iter 160000, Minibatch Loss= 178.346268
# Training Accuracy= 0.84375
# Iter 160640, Minibatch Loss= 199.677261
# Training Accuracy= 0.87500
# Iter 161280, Minibatch Loss= 119.617638
# Training Accuracy= 0.90625
# Iter 161920, Minibatch Loss= 402.946472
# Training Accuracy= 0.87500
# Iter 162560, Minibatch Loss= 177.471771
# Training Accuracy= 0.85938
# Iter 163200, Minibatch Loss= 122.215240
# Training Accuracy= 0.93750
# Iter 163840, Minibatch Loss= 63.368340
# Training Accuracy= 0.92188
# Iter 164480, Minibatch Loss= 175.078430
# Training Accuracy= 0.89062
# Iter 165120, Minibatch Loss= 93.536964
# Training Accuracy= 0.90625
# Iter 165760, Minibatch Loss= 129.919617
# Training Accuracy= 0.93750
# Iter 166400, Minibatch Loss= 185.176208
# Training Accuracy= 0.87500
# Iter 167040, Minibatch Loss= 176.432266
# Training Accuracy= 0.89062
# Iter 167680, Minibatch Loss= 132.851242
# Training Accuracy= 0.93750
# Iter 168320, Minibatch Loss= 361.351562
# Training Accuracy= 0.82812
# Iter 168960, Minibatch Loss= 60.304718
# Training Accuracy= 0.96875
# Iter 169600, Minibatch Loss= 309.009399
# Training Accuracy= 0.85938
# Iter 170240, Minibatch Loss= 179.844604
# Training Accuracy= 0.89062
# Iter 170880, Minibatch Loss= 128.251831
# Training Accuracy= 0.87500
# Iter 171520, Minibatch Loss= 121.738213
# Training Accuracy= 0.89062
# Iter 172160, Minibatch Loss= 89.163681
# Training Accuracy= 0.95312
# Iter 172800, Minibatch Loss= 101.753220
# Training Accuracy= 0.87500
# Iter 173440, Minibatch Loss= 118.194969
# Training Accuracy= 0.87500
# Iter 174080, Minibatch Loss= 249.488129
# Training Accuracy= 0.85938
# Iter 174720, Minibatch Loss= 167.038269
# Training Accuracy= 0.90625
# Iter 175360, Minibatch Loss= 278.249084
# Training Accuracy= 0.87500
# Iter 176000, Minibatch Loss= 218.713837
# Training Accuracy= 0.87500
# Iter 176640, Minibatch Loss= 253.463501
# Training Accuracy= 0.87500
# Iter 177280, Minibatch Loss= 227.205780
# Training Accuracy= 0.89062
# Iter 177920, Minibatch Loss= 484.296814
# Training Accuracy= 0.82812
# Iter 178560, Minibatch Loss= 98.405441
# Training Accuracy= 0.93750
# Iter 179200, Minibatch Loss= 101.089478
# Training Accuracy= 0.90625
# Iter 179840, Minibatch Loss= 170.283508
# Training Accuracy= 0.92188
# Iter 180480, Minibatch Loss= 124.367813
# Training Accuracy= 0.90625
# Iter 181120, Minibatch Loss= 181.080261
# Training Accuracy= 0.87500
# Iter 181760, Minibatch Loss= 99.451462
# Training Accuracy= 0.89062
# Iter 182400, Minibatch Loss= 156.328766
# Training Accuracy= 0.90625
# Iter 183040, Minibatch Loss= 89.340515
# Training Accuracy= 0.87500
# Iter 183680, Minibatch Loss= 273.544067
# Training Accuracy= 0.85938
# Iter 184320, Minibatch Loss= 207.781555
# Training Accuracy= 0.90625
# Iter 184960, Minibatch Loss= 160.477371
# Training Accuracy= 0.87500
# Iter 185600, Minibatch Loss= 160.290344
# Training Accuracy= 0.90625
# Iter 186240, Minibatch Loss= 59.151424
# Training Accuracy= 0.96875
# Iter 186880, Minibatch Loss= 214.829300
# Training Accuracy= 0.89062
# Iter 187520, Minibatch Loss= 32.331039
# Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 132.780090
# Training Accuracy= 0.89062
# Iter 188800, Minibatch Loss= 194.494766
# Training Accuracy= 0.87500
# Iter 189440, Minibatch Loss= 247.831573
# Training Accuracy= 0.84375
# Iter 190080, Minibatch Loss= 132.842102
# Training Accuracy= 0.90625
# Iter 190720, Minibatch Loss= 121.699013
# Training Accuracy= 0.95312
# Iter 191360, Minibatch Loss= 91.664818
# Training Accuracy= 0.90625
# Iter 192000, Minibatch Loss= 82.521683
# Training Accuracy= 0.92188
# Iter 192640, Minibatch Loss= 83.177124
# Training Accuracy= 0.92188
# Iter 193280, Minibatch Loss= 50.101482
# Training Accuracy= 0.95312
# Iter 193920, Minibatch Loss= 83.486580
# Training Accuracy= 0.90625
# Iter 194560, Minibatch Loss= 376.152893
# Training Accuracy= 0.85938
# Iter 195200, Minibatch Loss= 85.155792
# Training Accuracy= 0.90625
# Iter 195840, Minibatch Loss= 152.509811
# Training Accuracy= 0.92188
# Iter 196480, Minibatch Loss= 61.866817
# Training Accuracy= 0.93750
# Iter 197120, Minibatch Loss= 145.485321
# Training Accuracy= 0.92188
# Iter 197760, Minibatch Loss= 59.546814
# Training Accuracy= 0.96875
# Iter 198400, Minibatch Loss= 98.181732
# Training Accuracy= 0.90625
# Iter 199040, Minibatch Loss= 93.303360
# Training Accuracy= 0.90625
# Iter 199680, Minibatch Loss= 120.252335
# Training Accuracy= 0.84375
# Optimization Finished!
# Testing Accuracy: 0.9375
